# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('multiTimeline.csv', skiprows=1)

# %%
df.head()
# Out:
#      Month  gym: (Worldwide)
# 0  2004-01                52
# 1  2004-02                43
# 2  2004-03                41
# 3  2004-04                38
# 4  2004-05                39

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             248 non-null    object
#  1   gym: (Worldwide)  248 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 4.0+ KB

# %%
df.columns = ['Month','gym: (Worldwide)']

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df.head()
# Out:
#        Month  gym: (Worldwide)
# 0 2004-01-01                52
# 1 2004-02-01                43
# 2 2004-03-01                41
# 3 2004-04-01                38
# 4 2004-05-01                39

# %%
df.set_index('Month', inplace=True)

# %%
df.head()
# Out:
#             gym: (Worldwide)
# Month
# 2004-01-01                52
# 2004-02-01                43
# 2004-03-01                41
# 2004-04-01                38
# 2004-05-01                39

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df['gym: (Worldwide)'].rolling(12).mean().plot(label='12 Month Rolling Average')
# Out:
# <Axes: xlabel='Month'>
